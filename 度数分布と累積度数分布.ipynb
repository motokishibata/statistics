# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    '階級':['0~49','50~99','100~149','150~199','200~249','250~299','300~349','350~399'],
    '階級値':[25,75,125,175,225,275,325,375],
    '度数':[24,14,2,2,3,1,0,1],
    '相対度数':[0.5106,0.2979,0.0426,0.0426,0.0638,0.0213,0.0,0.0213],
    '累積相対度数':[0.5106,0.8085,0.8511,0.8936,0.9574,0.9787,0.9787,1.0]
})

plt.title("ヒストグラム", fontname="Meiryo")
plt.hist(df['度数'])
plt.show()

# ヒストグラムの調整は難しい
