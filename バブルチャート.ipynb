# %%
import pandas as pd

s1 = pd.Series([1,2,3,4])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df = pd.DataFrame({
    '玉入れ':[10,20,4],
    '綱引き':[150,30,8],
    'リレー':[50,15,1],
    '毛糸玉ころがし':[75,25,5],
    'にぼし食い競走':[60,30,5],
    'ムカデ競走':[125,35,9],
    '騎馬戦':[200,40,15],
}).transpose()

df.columns = ['参加匹数', '競技時間(分)', '怪我した猫(匹)']

print(df)
# Out:
#          参加匹数  競技時間(分)  怪我した猫(匹)
# 玉入れ        10       20         4
# 綱引き       150       30         8
# リレー        50       15         1
# 毛糸玉ころがし    75       25         5
# にぼし食い競走    60       30         5
# ムカデ競走     125       35         9
# 騎馬戦       200       40        15

# %%
import matplotlib.pyplot as plt

plt.scatter(df['参加匹数'], df['競技時間(分)'], df['怪我した猫(匹)'] * 100)
